# %%
# Examine differences in frame sequence for correct and wrong poses: 
import numpy as np
import matplotlib.pyplot as plt
import os

# %%
# sequence = np.load("/Users/cgusti/Desktop/Research/Yoga-pose-detection-and-correction-using-transformers/scripts/data/processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_1_sequence.npy")

# %%
# Define the folder path where you want to save the images
output_folder = "./visualizations_data_analysis"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# %%
# Assuming `data` is your loaded sequence of numpy arrays of shape (41, 17, 3)
# data = np.load('path_to_your_file.npy')

keypoints = ["nose", "left_eye", "right_eye", "left_ear", "right_ear", "left_shoulder", 
             "right_shoulder", "left_elbow","right_elbow", "left_wrist", "right_wrist",
             "left_hip", "right_hip", "left_knee", "right_knee", "left_ankle", "right_ankle"]

# Connections between keypoints to draw the body
connections = [
    ("nose", "left_eye"),
    ("nose", "right_eye"),
    ("left_eye", "left_ear"),
    ("right_eye", "right_ear"),
    ("left_shoulder", "right_shoulder"),
    ("left_shoulder", "left_elbow"),
    ("right_shoulder", "right_elbow"),
    ("left_elbow", "left_wrist"),
    ("right_elbow", "right_wrist"),
    ("left_hip", "right_hip"),
    ("left_shoulder", "left_hip"),
    ("right_shoulder", "right_hip"),
    ("left_hip", "left_knee"),
    ("right_hip", "right_knee"),
    ("left_knee", "left_ankle"),
    ("right_knee", "right_ankle")
]

# %%
# Function to plot the keypoints and connections for one frame
def plot_frame(frame_data, sequence_num, sequence_name, output_folder):
    plt.figure(figsize=(8, 8))
    plt.scatter(frame_data[:, 0], frame_data[:, 1], s=50, c='red')  # plot keypoints
    for connection in connections:
        start, end = connection
        x_values = [frame_data[keypoints.index(start), 0], frame_data[keypoints.index(end), 0]]
        y_values = [frame_data[keypoints.index(start), 1], frame_data[keypoints.index(end), 1]]
        plt.plot(x_values, y_values, 'k-')  # plot connection lines

    # Annotate keypoints with labels
    for i, point in enumerate(keypoints):
        plt.text(frame_data[i, 0], frame_data[i, 1], point, fontsize=10, color='blue')
        
    plt.gca().invert_yaxis()  # Y-axis inversion is optional; it depends on your coordinatfile system
    plt.title(f"{sequence_name} Frame {sequence_num}")  # Use the sequence_num in the title

    #Ensure the directory exists
    directory = os.path.join(output_folder, sequence_name)
    if not os.path.exists(directory):
        os.makedirs(directory)
        
    #Save the plot as an image
    filename = f"{output_folder}/{sequence_name}/frame_sequence_{sequence_num}"
    plt.savefig(filename)
    print(f"saved: {filename}")
    
    plt.close()

# %%
dir_correct = 'processed_frames/numerical/WarriorTwo/correct/'
filepath_list_correct = [os.path.join(dir_correct, file_name) for file_name in os.listdir(dir_correct)]
print(filepath_list_correct)

dir_wrong = 'processed_frames/numerical/WarriorTwo/wrong/'
filepath_list_wrong = [os.path.join(dir_wrong, file_name) for file_name in os.listdir(dir_wrong)]
print(filepath_list_wrong)


# Define the folder path where you want to save the images
output_folder = "./visualizations_data_analysis"
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Loop through the sequence and visualize each frame's pose for correct sequences
for filepath in filepath_list_correct:
    name = os.path.basename(filepath).rsplit('.', 1)[0]
    sequence = np.load(filepath)
    for index, frame in enumerate(sequence):
        plot_frame(frame, sequence_num=index+1, sequence_name=name, output_folder=output_folder)  # Pass the current sequence/frame number

# Loop through the sequence and visualize each frame's pose for wrong sequences 
for filepath in filepath_list_wrong:
    name = os.path.basename(filepath).rsplit('.', 1)[0]
    sequence = np.load(filepath)
    for index, frame in enumerate(sequence):
        plot_frame(frame, sequence_num=index+1, sequence_name=name, output_folder=output_folder)  # Pass the current sequence/frame number
# Out:
# ['processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_7_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_6_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_1_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_3_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_4_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_5_sequence.npy', 'processed_frames/numerical/WarriorTwo/correct/WarriorTwo_correct_2_sequence.npy']
# ['processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_9_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_8_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_10_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_5_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_2_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_11_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_3_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_4_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_6_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_1_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_12_sequence.npy', 'processed_frames/numerical/WarriorTwo/wrong/WarriorTwo_wrong_7_sequence.npy']
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_correct_7_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_correct_6_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_27
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_28
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_29
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_30
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_31
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_32
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_33
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_34
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_35
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_36
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_37
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_38
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_39
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_40
# saved: ./visualizations_data_analysis/WarriorTwo_correct_1_sequence/frame_sequence_41
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_3_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_27
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_28
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_29
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_30
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_31
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_32
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_33
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_34
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_35
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_36
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_37
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_38
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_39
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_40
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_41
# saved: ./visualizations_data_analysis/WarriorTwo_correct_4_sequence/frame_sequence_42
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_5_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_correct_2_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_9_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_8_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_10_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_5_sequence/frame_sequence_27
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_2_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_11_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_3_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_4_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_27
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_28
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_29
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_6_sequence/frame_sequence_30
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_1_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_12_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_12_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_12_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_1
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_2
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_3
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_4
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_5
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_6
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_7
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_8
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_9
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_10
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_11
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_12
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_13
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_14
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_15
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_16
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_17
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_18
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_19
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_20
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_21
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_22
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_23
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_24
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_25
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_26
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_27
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_28
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_29
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_30
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_31
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_32
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_33
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_34
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_35
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_36
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_37
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_38
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_39
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_40
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_41
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_42
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_43
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_44
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_45
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_46
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_47
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_48
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_49
# saved: ./visualizations_data_analysis/WarriorTwo_wrong_7_sequence/frame_sequence_50

# %% [markdown]
# ### Visualizing Angle Tracking Overtime

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

def process_and_save_files(directory):
    # Check if the specified directory exists
    if not os.path.exists(directory):
        print(f"Directory '{directory}' does not exist.")
        return

    # Get a list of all .npz files in the directory
    npz_files = [f for f in os.listdir(directory) if f.endswith(".npz")]

    for npz_file in npz_files:
        # Construct the full file path
        file_path = os.path.join(directory, npz_file)

        # Load the data from the .npz file
        loaded_data = np.load(file_path)
        bent_leg = loaded_data['bent_leg']
        torso_bend = loaded_data['torso_bend']
        hip_bend = loaded_data['hip_bend']

        # Extract the file name without extension
        file_name_no_extension = os.path.splitext(npz_file)[0]

        # Create a directory with the same name as the file
        save_dir = os.path.join(directory, file_name_no_extension)
        os.makedirs(save_dir, exist_ok=True)

        # Plot and save the time series analysis for each array
        plt.figure()
        plt.plot(bent_leg, label='Bent Leg')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Bent Leg Time Series Analysis')
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'bent_leg_plot.png'))
        plt.close()

        plt.figure()
        plt.plot(torso_bend, label='Torso Bend')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Torso Bend Time Series Analysis')
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'torso_bend_plot.png'))
        plt.close()

        plt.figure()
        plt.plot(hip_bend, label='Hip Bend')
        plt.xlabel('Time')
        plt.ylabel('Value')
        plt.title('Hip Bend Time Series Analysis')
        plt.legend()
        plt.savefig(os.path.join(save_dir, 'hip_bend_plot.png'))
        plt.close()

# %%
directory = './angle_analysis/'
process_and_save_files(directory)
